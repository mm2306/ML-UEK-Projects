# %% [markdown]
# # Step 1: Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error
import tensorflow as tf
from keras import Model
from keras.layers import Input, Dense, Dropout
from keras.layers import LSTM

# %% [markdown]
# # Step 2: Reading Dataset

# %%
df = pd.read_csv('../datasets/gold-dataset.csv')

# %% [markdown]
# # Step 3: Dataset Overview

# %%
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2011-12-15  154.740005  154.949997  151.710007  152.330002  152.330002
# 1     2011-12-16  154.309998  155.369995  153.899994  155.229996  155.229996
# 2     2011-12-19  155.479996  155.860001  154.360001  154.869995  154.869995
# 3     2011-12-20  156.820007  157.429993  156.580002  156.979996  156.979996
# 4     2011-12-21  156.979996  157.529999  156.130005  157.160004  157.160004
# ...          ...         ...         ...         ...         ...         ...
# 1713  2018-12-24  119.570000  120.139999  119.570000  120.019997  120.019997
# 1714  2018-12-26  120.620003  121.000000  119.570000  119.660004  119.660004
# 1715  2018-12-27  120.570000  120.900002  120.139999  120.570000  120.570000
# 1716  2018-12-28  120.800003  121.080002  120.720001  121.059998  121.059998
# 1717  2018-12-31  120.980003  121.260002  120.830002  121.250000  121.250000
#
#         Volume     SP_open     SP_high      SP_low  ...    GDX_Low  GDX_Close  \
# 0     21521900  123.029999  123.199997  121.989998  ...  51.570000  51.680000
# 1     18124300  122.230003  122.949997  121.300003  ...  52.040001  52.680000
# 2     12547200  122.059998  122.320000  120.029999  ...  51.029999  51.169998
# 3      9136300  122.180000  124.139999  120.370003  ...  52.369999  52.990002
# 4     11996100  123.930000  124.360001  122.750000  ...  52.419998  52.959999
# ...        ...         ...         ...         ...  ...        ...        ...
# 1713   9736400  239.039993  240.839996  234.270004  ...  20.650000  21.090000
# 1714  14293500  235.970001  246.179993  233.759995  ...  20.530001  20.620001
# 1715  11874400  242.570007  248.289993  238.960007  ...  20.700001  20.969999
# 1716   6864700  249.580002  251.399994  246.449997  ...  20.570000  20.600000
# 1717   8449400  249.559998  250.190002  247.470001  ...  20.559999  21.090000
#
#       GDX_Adj Close  GDX_Volume   USO_Open   USO_High    USO_Low  USO_Close  \
# 0         48.973877    20605600  36.900002  36.939999  36.049999  36.130001
# 1         49.921513    16285400  36.180000  36.500000  35.730000  36.270000
# 2         48.490578    15120200  36.389999  36.450001  35.930000  36.200001
# 3         50.215282    11644900  37.299999  37.610001  37.220001  37.560001
# 4         50.186852     8724300  37.669998  38.240002  37.520000  38.110001
# ...             ...         ...        ...        ...        ...        ...
# 1713      21.090000    60507000   9.490000   9.520000   9.280000   9.290000
# 1714      20.620001    76365200   9.250000   9.920000   9.230000   9.900000
# 1715      20.969999    52393000   9.590000   9.650000   9.370000   9.620000
# 1716      20.600000    49835000   9.540000   9.650000   9.380000   9.530000
# 1717      21.090000    53866600   9.630000   9.710000   9.440000   9.660000
#
#       USO_Adj Close  USO_Volume
# 0         36.130001    12616700
# 1         36.270000    12578800
# 2         36.200001     7418200
# 3         37.560001    10041600
# 4         38.110001    10728000
# ...             ...         ...
# 1713       9.290000    21598200
# 1714       9.900000    40978800
# 1715       9.620000    36578700
# 1716       9.530000    22803400
# 1717       9.660000    28417400
#
# [1718 rows x 81 columns]

# %% [markdown]
# __As you can see, the data set includes daily gold price information including daily Open, High and Low prices and the final price of each day (Price) along with the volume of transactions and price changes in each day.__

# %% [markdown]
# __Dataset Basic Information:__

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1718 entries, 0 to 1717
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           1718 non-null   str
#  1   Open           1718 non-null   float64
#  2   High           1718 non-null   float64
#  3   Low            1718 non-null   float64
#  4   Close          1718 non-null   float64
#  5   Adj Close      1718 non-null   float64
#  6   Volume         1718 non-null   int64
#  7   SP_open        1718 non-null   float64
#  8   SP_high        1718 non-null   float64
#  9   SP_low         1718 non-null   float64
#  10  SP_close       1718 non-null   float64
#  11  SP_Ajclose     1718 non-null   float64
#  12  SP_volume      1718 non-null   int64
#  13  DJ_open        1718 non-null   float64
#  14  DJ_high        1718 non-null   float64
#  15  DJ_low         1718 non-null   float64
#  16  DJ_close       1718 non-null   float64
#  17  DJ_Ajclose     1718 non-null   float64
#  18  DJ_volume      1718 non-null   int64
#  19  EG_open        1718 non-null   float64
#  20  EG_high        1718 non-null   float64
#  21  EG_low         1718 non-null   float64
#  22  EG_close       1718 non-null   float64
#  23  EG_Ajclose     1718 non-null   float64
#  24  EG_volume      1718 non-null   int64
#  25  EU_Price       1718 non-null   float64
#  26  EU_open        1718 non-null   float64
#  27  EU_high        1718 non-null   float64
#  28  EU_low         1718 non-null   float64
#  29  EU_Trend       1718 non-null   int64
#  30  OF_Price       1718 non-null   float64
#  31  OF_Open        1718 non-null   float64
#  32  OF_High        1718 non-null   float64
#  33  OF_Low         1718 non-null   float64
#  34  OF_Volume      1718 non-null   int64
#  35  OF_Trend       1718 non-null   int64
#  36  OS_Price       1718 non-null   float64
#  37  OS_Open        1718 non-null   float64
#  38  OS_High        1718 non-null   float64
#  39  OS_Low         1718 non-null   float64
#  40  OS_Trend       1718 non-null   int64
#  41  SF_Price       1718 non-null   int64
#  42  SF_Open        1718 non-null   int64
#  43  SF_High        1718 non-null   int64
#  44  SF_Low         1718 non-null   int64
#  45  SF_Volume      1718 non-null   int64
#  46  SF_Trend       1718 non-null   int64
#  47  USB_Price      1718 non-null   float64
#  48  USB_Open       1718 non-null   float64
#  49  USB_High       1718 non-null   float64
#  50  USB_Low        1718 non-null   float64
#  51  USB_Trend      1718 non-null   int64
#  52  PLT_Price      1718 non-null   float64
#  53  PLT_Open       1718 non-null   float64
#  54  PLT_High       1718 non-null   float64
#  55  PLT_Low        1718 non-null   float64
#  56  PLT_Trend      1718 non-null   int64
#  57  PLD_Price      1718 non-null   float64
#  58  PLD_Open       1718 non-null   float64
#  59  PLD_High       1718 non-null   float64
#  60  PLD_Low        1718 non-null   float64
#  61  PLD_Trend      1718 non-null   int64
#  62  RHO_PRICE      1718 non-null   int64
#  63  USDI_Price     1718 non-null   float64
#  64  USDI_Open      1718 non-null   float64
#  65  USDI_High      1718 non-null   float64
#  66  USDI_Low       1718 non-null   float64
#  67  USDI_Volume    1718 non-null   int64
#  68  USDI_Trend     1718 non-null   int64
#  69  GDX_Open       1718 non-null   float64
#  70  GDX_High       1718 non-null   float64
#  71  GDX_Low        1718 non-null   float64
#  72  GDX_Close      1718 non-null   float64
#  73  GDX_Adj Close  1718 non-null   float64
#  74  GDX_Volume     1718 non-null   int64
#  75  USO_Open       1718 non-null   float64
#  76  USO_High       1718 non-null   float64
#  77  USO_Low        1718 non-null   float64
#  78  USO_Close      1718 non-null   float64
#  79  USO_Adj Close  1718 non-null   float64
#  80  USO_Volume     1718 non-null   int64
# dtypes: float64(58), int64(22), str(1)
# memory usage: 1.1 MB

# %% [markdown]
# __All variables are stored as object.__

# %% [markdown]
# # Step 4: Data Preparation

# %% [markdown]
# ## Step 4.1: Feature Subset Selection
# __Since we will not use Vol. and Change % features to predict Price, we will drop these two features:__

# %%
df = df[['Date', 'Close']].rename(columns={'Close': 'Price'})

# %% [markdown]
# ## Step 4.2: Transforming Data

# %% [markdown]
# __Date feature is stored as object in the data frame. To increase the speed of calculations, we convert it's data type to datetime and then sort this feature in ascending order:__

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.sort_values(by='Date', ascending=True, inplace=True)
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# __The " , " sign is redundant in the dataset. First, we remove it from the entire dataset and then change the data type of the numerical variables to float:__

# %%
NumCols = df.columns.drop(['Date'])
df[NumCols] = df[NumCols].astype('float64')

# %% [markdown]
# __Result:__

# %%
df.head()
# Out:
#         Date       Price
# 0 2011-12-15  152.330002
# 1 2011-12-16  155.229996
# 2 2011-12-19  154.869995
# 3 2011-12-20  156.979996
# 4 2011-12-21  157.160004

# %% [markdown]
# ## Step 4.3: Checking Duplicates
# __There are no duplicate samples in Date feature:__

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Step 4.4: Checking Missing Values
# __There are no missing values in the dataset:__

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Step 5: Visualizing Gold Price History Data
#
# __Interactive Gold Price Chart:__

# %%
fig = px.line(y=df.Price, x=df.Date)
fig.update_traces(line_color='black') 
fig.update_layout(xaxis_title="Date", 
                  yaxis_title="Scaled Price",
                  title={'text': "Gold Price History Data", 'y':0.95, 'x':0.5, 'xanchor':'center', 'yanchor':'top'},
                  plot_bgcolor='rgba(255,223,0,0.8)')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\plotly\basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\plotly\io\_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'hovertemplate': 'x=%{x}<br>y=%{y}<extra></extra>',
#               'legendgroup': '',
#               'line': {'color': 'black', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines',
#               'name': '',
#               'showlegend': False,
#               'type': 'scattergl',
#               'x': array(['2011-12-15T00:00:00.000000', '2011-12-16T00:00:00.000000',
#                           '2011-12-19T00:00:00.000000', ..., '2018-12-27T00:00:00.000000',
#                           '2018-12-28T00:00:00.000000', '2018-12-31T00:00:00.000000'],
#                          shape=(1718,), dtype='datetime64[us]'),
#               'xaxis': 'x',
#               'y': {'bdata': ('q7NaYI8KY0C/RpIgXGdjQN8Vwf/WW2' ... 'F6JF5A0/TZAddDXkAAAAAAAFBeQA=='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'}],
#     'layout': {'legend': {'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'plot_bgcolor': 'rgba(255,223,0,0.8)',
#                'template': '...',
#                'title': {'text': 'Gold Price History Data', 'x': 0.5, 'xanchor': 'center', 'y': 0.95, 'yanchor': 'top'},
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'Date'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'Scaled Price'}}}
# })

# %% [markdown]
# # Step 6: Splitting Data to Training & Test Sets
# __Since we cannot train on future data in time series data, we should not divide the time series data randomly. In time series splitting, testing set is always later than training set. We consider the last year for testing and everything else for training:__

# %%
test_size = df[df.Date.dt.year==2018].shape[0]
test_size
# Out:
# 248

# %% [markdown]
# __Gold Price Training and Test Sets Plot:__

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 5), dpi=150)

axes[0].plot(df.Date[:-test_size], df.Price[:-test_size], color='black', lw=1.5)
axes[0].set_title(f'Training Set ({len(df)-test_size} Tage)', fontsize=14)
axes[0].set_xlabel('Date', fontsize=11)
axes[0].set_ylabel('Price ($)', fontsize=11)
axes[0].grid(True, alpha=0.3)

axes[1].plot(df.Date[-test_size:], df.Price[-test_size:], color='blue', lw=1.5)
axes[1].set_title(f'Test Set ({test_size} Tage – Jahr 2018)', fontsize=14)
axes[1].set_xlabel('Date', fontsize=11)
axes[1].set_ylabel('Price ($)', fontsize=11)
axes[1].grid(True, alpha=0.3)

plt.suptitle('Gold Price – Training vs Test Data', fontsize=16, y=1.02)
plt.tight_layout()
plt.show()

plt.figure(figsize=(15, 5), dpi=150)
plt.plot(df.Date[:-test_size], df.Price[:-test_size], color='black', lw=2, label='Training')
plt.plot(df.Date[-test_size:], df.Price[-test_size:], color='blue', lw=2, label='Test')
plt.axvline(x=df.Date.iloc[-test_size], color='red', linestyle='--', lw=1.5, label='Train/Test Split')
plt.title('Gold Price – Gesamtverlauf mit Train/Test Split', fontsize=15)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price ($)', fontsize=12)
plt.legend(loc='upper left', prop={'size': 12})
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Step 7: Data Scaling
# __Since we aim to predict Price only based on its historical data, we scale Price using MinMaxScaler to avoid intensive computations:__

# %%
scaler = MinMaxScaler()
scaler.fit(df.Price[:-test_size].values.reshape(-1,1))
# Out:
# MinMaxScaler()

# %% [markdown]
# # Step 8: Restructure Data & Create Sliding Window
# __The use of prior time steps to predict the next time step is called sliding window. In this way, time series data can be expressed as supervised learning. We can do this by using previous time steps as input variables and use the next time step as the output variable. The number of previous time steps is called the window width. Here we set window width to 60. Therefore, X_train and X_test will be nested lists containing lists of 60 time-stamp prices. y_train and y_test are also lists of gold prices containing the next day's gold price corresponds to each list in X_train and X_test respectively:__

# %%
window_size = 60

# %% [markdown]
# __Training Set:__

# %%
train_data = df.Price[:-test_size]
train_data = scaler.transform(train_data.values.reshape(-1,1))

# %%
X_train = []
y_train = []

for i in range(window_size, len(train_data)):
    X_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])

# %% [markdown]
# __Test Set:__

# %%
test_data = df.Price[-test_size-60:]
test_data = scaler.transform(test_data.values.reshape(-1,1))

# %%
X_test = []
y_test = []

for i in range(window_size, len(test_data)):
    X_test.append(test_data[i-60:i, 0])
    y_test.append(test_data[i, 0])

# %% [markdown]
# # Step 9: Converting Data to Numpy Arrays
#
# __Now X_train and X_test are nested lists (two-dimensional lists) and y_train is a one-dimensional list. We need to convert them to numpy arrays with a higher dimension, which is the data format accepted by TensorFlow when training the neural network:__

# %%
X_train = np.array(X_train)
X_test  = np.array(X_test)
y_train = np.array(y_train)
y_test  = np.array(y_test)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test  = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
y_train = np.reshape(y_train, (-1,1))
y_test  = np.reshape(y_test, (-1,1))

# %%
print('X_train Shape: ', X_train.shape)
print('y_train Shape: ', y_train.shape)
print('X_test Shape:  ', X_test.shape)
print('y_test Shape:  ', y_test.shape)
# Out:
# X_train Shape:  (1410, 60, 1)
# y_train Shape:  (1410, 1)
# X_test Shape:   (248, 60, 1)
# y_test Shape:   (248, 1)

# %% [markdown]
# # Step 10: Creating an LSTM Network
# __We build an LSTM network, which is a type of Recurrent Neural Networks designed to solve vanishing gradient problem:__

# %% [markdown]
# __Model Definition:__

# %%
def define_model():
    input1 = Input(shape=(window_size,1))
    x = LSTM(units = 64, return_sequences=True)(input1)  
    x = Dropout(0.2)(x)
    x = LSTM(units = 64, return_sequences=True)(x)
    x = Dropout(0.2)(x)
    x = LSTM(units = 64)(x)
    x = Dropout(0.2)(x)
    x = Dense(32, activation='relu')(x)
    dnn_output = Dense(1)(x)

    model = Model(inputs=input1, outputs=[dnn_output])
    model.compile(loss='mean_squared_error', optimizer='Nadam')
    model.summary()
    
    return model

# %% [markdown]
# __Model Training:__

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=20,
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=8,
    min_lr=1e-6
)

model = define_model()
history = model.fit(
    X_train,
    y_train,
    epochs=300,  # hoch setzen, EarlyStopping stoppt automatisch
    batch_size=32,
    validation_split=0.1,  # falls du erstmal nichts am Split ändern willst
    callbacks=[early_stopping, reduce_lr],
    shuffle=False,         # fuer Zeitreihen wichtig
    verbose=1
)
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 60, 1)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_12 (LSTM)                  │ (None, 60, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 60, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_13 (LSTM)                  │ (None, 60, 64)         │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 60, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_14 (LSTM)                  │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 85,057 (332.25 KB)
#  Trainable params: 85,057 (332.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 9s 92ms/step - loss: 0.0438 - val_loss: 8.1298e-04 - learning_rate: 0.0010
# Epoch 2/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - loss: 0.0070 - val_loss: 7.8859e-04 - learning_rate: 0.0010
# Epoch 3/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0086 - val_loss: 0.0011 - learning_rate: 0.0010
# Epoch 4/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 90ms/step - loss: 0.0115 - val_loss: 0.0014 - learning_rate: 0.0010
# Epoch 5/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0164 - val_loss: 9.6561e-04 - learning_rate: 0.0010
# Epoch 6/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0195 - val_loss: 0.0015 - learning_rate: 0.0010
# Epoch 7/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 0.0247 - val_loss: 0.0010 - learning_rate: 0.0010
# Epoch 8/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 0.0249 - val_loss: 9.7273e-04 - learning_rate: 0.0010
# Epoch 9/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step - loss: 0.0273 - val_loss: 0.0020 - learning_rate: 0.0010
# Epoch 10/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 0.0376 - val_loss: 8.7214e-04 - learning_rate: 5.0000e-04
# Epoch 11/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - loss: 0.0191 - val_loss: 0.0024 - learning_rate: 5.0000e-04
# Epoch 12/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - loss: 0.0104 - val_loss: 7.9991e-04 - learning_rate: 5.0000e-04
# Epoch 13/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 0.0035 - val_loss: 6.9278e-04 - learning_rate: 5.0000e-04
# Epoch 14/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - loss: 0.0034 - val_loss: 6.5107e-04 - learning_rate: 5.0000e-04
# Epoch 15/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 0.0032 - val_loss: 6.4004e-04 - learning_rate: 5.0000e-04
# Epoch 16/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 0.0034 - val_loss: 6.3622e-04 - learning_rate: 5.0000e-04
# Epoch 17/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 0.0033 - val_loss: 6.1795e-04 - learning_rate: 5.0000e-04
# Epoch 18/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - loss: 0.0028 - val_loss: 6.2803e-04 - learning_rate: 5.0000e-04
# Epoch 19/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 0.0033 - val_loss: 5.9442e-04 - learning_rate: 5.0000e-04
# Epoch 20/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 0.0031 - val_loss: 6.0603e-04 - learning_rate: 5.0000e-04
# Epoch 21/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - loss: 0.0029 - val_loss: 5.8240e-04 - learning_rate: 5.0000e-04
# Epoch 22/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 135ms/step - loss: 0.0030 - val_loss: 5.9875e-04 - learning_rate: 5.0000e-04
# Epoch 23/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 9s 236ms/step - loss: 0.0028 - val_loss: 5.5742e-04 - learning_rate: 5.0000e-04
# Epoch 24/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - loss: 0.0031 - val_loss: 5.6177e-04 - learning_rate: 5.0000e-04
# Epoch 25/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - loss: 0.0027 - val_loss: 5.6605e-04 - learning_rate: 5.0000e-04
# Epoch 26/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 182ms/step - loss: 0.0032 - val_loss: 5.4888e-04 - learning_rate: 5.0000e-04
# Epoch 27/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 8s 202ms/step - loss: 0.0029 - val_loss: 5.2845e-04 - learning_rate: 5.0000e-04
# Epoch 28/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 8s 190ms/step - loss: 0.0027 - val_loss: 5.2890e-04 - learning_rate: 5.0000e-04
# Epoch 29/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 180ms/step - loss: 0.0026 - val_loss: 5.3190e-04 - learning_rate: 5.0000e-04
# Epoch 30/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 8s 209ms/step - loss: 0.0032 - val_loss: 5.8101e-04 - learning_rate: 2.5000e-04
# Epoch 31/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 8s 192ms/step - loss: 0.0021 - val_loss: 5.2769e-04 - learning_rate: 2.5000e-04
# Epoch 32/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 177ms/step - loss: 0.0023 - val_loss: 5.4553e-04 - learning_rate: 2.5000e-04
# Epoch 33/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 175ms/step - loss: 0.0023 - val_loss: 5.2678e-04 - learning_rate: 2.5000e-04
# Epoch 34/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 170ms/step - loss: 0.0022 - val_loss: 5.3297e-04 - learning_rate: 2.5000e-04
# Epoch 35/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 163ms/step - loss: 0.0022 - val_loss: 5.2952e-04 - learning_rate: 2.5000e-04
# Epoch 36/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 177ms/step - loss: 0.0022 - val_loss: 5.2138e-04 - learning_rate: 2.5000e-04
# Epoch 37/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 177ms/step - loss: 0.0022 - val_loss: 5.2685e-04 - learning_rate: 2.5000e-04
# Epoch 38/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 177ms/step - loss: 0.0020 - val_loss: 5.2578e-04 - learning_rate: 1.2500e-04
# Epoch 39/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 61ms/step - loss: 0.0020 - val_loss: 5.1252e-04 - learning_rate: 1.2500e-04
# Epoch 40/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 0.0020 - val_loss: 5.1685e-04 - learning_rate: 1.2500e-04
# Epoch 41/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 0.0021 - val_loss: 5.1402e-04 - learning_rate: 1.2500e-04
# Epoch 42/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 0.0021 - val_loss: 5.1705e-04 - learning_rate: 1.2500e-04
# Epoch 43/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 0.0021 - val_loss: 5.1474e-04 - learning_rate: 1.2500e-04
# Epoch 44/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 0.0020 - val_loss: 5.1217e-04 - learning_rate: 1.2500e-04
# Epoch 45/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 0.0020 - val_loss: 5.1030e-04 - learning_rate: 1.2500e-04
# Epoch 46/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 0.0020 - val_loss: 5.0135e-04 - learning_rate: 6.2500e-05
# Epoch 47/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 0.0020 - val_loss: 5.0633e-04 - learning_rate: 6.2500e-05
# Epoch 48/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 0.0019 - val_loss: 5.0513e-04 - learning_rate: 6.2500e-05
# Epoch 49/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 129ms/step - loss: 0.0019 - val_loss: 5.0385e-04 - learning_rate: 6.2500e-05
# Epoch 50/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 0.0018 - val_loss: 5.0387e-04 - learning_rate: 6.2500e-05
# Epoch 51/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 0.0019 - val_loss: 5.0414e-04 - learning_rate: 6.2500e-05
# Epoch 52/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 0.0020 - val_loss: 4.9666e-04 - learning_rate: 6.2500e-05
# Epoch 53/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 0.0020 - val_loss: 4.9763e-04 - learning_rate: 6.2500e-05
# Epoch 54/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 0.0018 - val_loss: 4.9639e-04 - learning_rate: 3.1250e-05
# Epoch 55/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 8s 206ms/step - loss: 0.0021 - val_loss: 4.9656e-04 - learning_rate: 3.1250e-05
# Epoch 56/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 8s 195ms/step - loss: 0.0020 - val_loss: 4.9546e-04 - learning_rate: 3.1250e-05
# Epoch 57/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 10s 177ms/step - loss: 0.0019 - val_loss: 4.9585e-04 - learning_rate: 3.1250e-05
# Epoch 58/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 171ms/step - loss: 0.0020 - val_loss: 4.9778e-04 - learning_rate: 3.1250e-05
# Epoch 59/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 8s 190ms/step - loss: 0.0020 - val_loss: 4.9655e-04 - learning_rate: 3.1250e-05
# Epoch 60/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 179ms/step - loss: 0.0020 - val_loss: 4.9621e-04 - learning_rate: 3.1250e-05
# Epoch 61/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 179ms/step - loss: 0.0019 - val_loss: 4.9429e-04 - learning_rate: 3.1250e-05
# Epoch 62/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 178ms/step - loss: 0.0020 - val_loss: 4.9451e-04 - learning_rate: 1.5625e-05
# Epoch 63/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 184ms/step - loss: 0.0019 - val_loss: 4.9436e-04 - learning_rate: 1.5625e-05
# Epoch 64/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 153ms/step - loss: 0.0018 - val_loss: 4.9442e-04 - learning_rate: 1.5625e-05
# Epoch 65/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 181ms/step - loss: 0.0019 - val_loss: 4.9456e-04 - learning_rate: 1.5625e-05
# Epoch 66/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 172ms/step - loss: 0.0020 - val_loss: 4.9371e-04 - learning_rate: 1.5625e-05
# Epoch 67/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 177ms/step - loss: 0.0018 - val_loss: 4.9230e-04 - learning_rate: 1.5625e-05
# Epoch 68/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 159ms/step - loss: 0.0018 - val_loss: 4.9400e-04 - learning_rate: 1.5625e-05
# Epoch 69/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - loss: 0.0020 - val_loss: 4.9316e-04 - learning_rate: 1.5625e-05
# Epoch 70/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 8s 211ms/step - loss: 0.0019 - val_loss: 4.9255e-04 - learning_rate: 7.8125e-06
# Epoch 71/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 8s 191ms/step - loss: 0.0018 - val_loss: 4.9245e-04 - learning_rate: 7.8125e-06
# Epoch 72/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 8s 186ms/step - loss: 0.0019 - val_loss: 4.9180e-04 - learning_rate: 7.8125e-06
# Epoch 73/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 173ms/step - loss: 0.0019 - val_loss: 4.9148e-04 - learning_rate: 7.8125e-06
# Epoch 74/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 170ms/step - loss: 0.0018 - val_loss: 4.9104e-04 - learning_rate: 7.8125e-06
# Epoch 75/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - loss: 0.0018 - val_loss: 4.9039e-04 - learning_rate: 7.8125e-06
# Epoch 76/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 0.0019 - val_loss: 4.9015e-04 - learning_rate: 7.8125e-06
# Epoch 77/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 0.0019 - val_loss: 4.8980e-04 - learning_rate: 7.8125e-06
# Epoch 78/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0019 - val_loss: 4.8994e-04 - learning_rate: 3.9063e-06
# Epoch 79/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0019 - val_loss: 4.8961e-04 - learning_rate: 3.9063e-06
# Epoch 80/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0018 - val_loss: 4.8901e-04 - learning_rate: 3.9063e-06
# Epoch 81/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0018 - val_loss: 4.8890e-04 - learning_rate: 3.9063e-06
# Epoch 82/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0019 - val_loss: 4.8903e-04 - learning_rate: 3.9063e-06
# Epoch 83/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0020 - val_loss: 4.8902e-04 - learning_rate: 3.9063e-06
# Epoch 84/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0019 - val_loss: 4.8879e-04 - learning_rate: 3.9063e-06
# Epoch 85/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.0020 - val_loss: 4.8868e-04 - learning_rate: 3.9063e-06
# Epoch 86/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.0018 - val_loss: 4.8855e-04 - learning_rate: 1.9531e-06
# Epoch 87/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0019 - val_loss: 4.8861e-04 - learning_rate: 1.9531e-06
# Epoch 88/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0020 - val_loss: 4.8835e-04 - learning_rate: 1.9531e-06
# Epoch 89/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0020 - val_loss: 4.8855e-04 - learning_rate: 1.9531e-06
# Epoch 90/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0018 - val_loss: 4.8840e-04 - learning_rate: 1.9531e-06
# Epoch 91/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 0.0019 - val_loss: 4.8841e-04 - learning_rate: 1.9531e-06
# Epoch 92/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0019 - val_loss: 4.8845e-04 - learning_rate: 1.9531e-06
# Epoch 93/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0018 - val_loss: 4.8856e-04 - learning_rate: 1.9531e-06
# Epoch 94/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step - loss: 0.0019 - val_loss: 4.8865e-04 - learning_rate: 1.0000e-06
# Epoch 95/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 81ms/step - loss: 0.0018 - val_loss: 4.8852e-04 - learning_rate: 1.0000e-06
# Epoch 96/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0018 - val_loss: 4.8831e-04 - learning_rate: 1.0000e-06
# Epoch 97/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 0.0019 - val_loss: 4.8810e-04 - learning_rate: 1.0000e-06
# Epoch 98/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0019 - val_loss: 4.8822e-04 - learning_rate: 1.0000e-06
# Epoch 99/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 0.0018 - val_loss: 4.8820e-04 - learning_rate: 1.0000e-06
# Epoch 100/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 0.0018 - val_loss: 4.8817e-04 - learning_rate: 1.0000e-06
# Epoch 101/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 0.0019 - val_loss: 4.8829e-04 - learning_rate: 1.0000e-06
# Epoch 102/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 0.0020 - val_loss: 4.8832e-04 - learning_rate: 1.0000e-06
# Epoch 103/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 0.0019 - val_loss: 4.8837e-04 - learning_rate: 1.0000e-06
# Epoch 104/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 0.0019 - val_loss: 4.8849e-04 - learning_rate: 1.0000e-06
# Epoch 105/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 0.0018 - val_loss: 4.8837e-04 - learning_rate: 1.0000e-06
# Epoch 106/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 0.0019 - val_loss: 4.8829e-04 - learning_rate: 1.0000e-06
# Epoch 107/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0019 - val_loss: 4.8832e-04 - learning_rate: 1.0000e-06
# Epoch 108/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0019 - val_loss: 4.8824e-04 - learning_rate: 1.0000e-06
# Epoch 109/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0018 - val_loss: 4.8817e-04 - learning_rate: 1.0000e-06
# Epoch 110/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0019 - val_loss: 4.8815e-04 - learning_rate: 1.0000e-06
# Epoch 111/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.0019 - val_loss: 4.8805e-04 - learning_rate: 1.0000e-06
# Epoch 112/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0018 - val_loss: 4.8792e-04 - learning_rate: 1.0000e-06
# Epoch 113/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 0.0018 - val_loss: 4.8793e-04 - learning_rate: 1.0000e-06
# Epoch 114/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.0020 - val_loss: 4.8798e-04 - learning_rate: 1.0000e-06
# Epoch 115/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0019 - val_loss: 4.8791e-04 - learning_rate: 1.0000e-06
# Epoch 116/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.0019 - val_loss: 4.8791e-04 - learning_rate: 1.0000e-06
# Epoch 117/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0019 - val_loss: 4.8778e-04 - learning_rate: 1.0000e-06
# Epoch 118/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0019 - val_loss: 4.8761e-04 - learning_rate: 1.0000e-06
# Epoch 119/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0019 - val_loss: 4.8764e-04 - learning_rate: 1.0000e-06
# Epoch 120/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0019 - val_loss: 4.8764e-04 - learning_rate: 1.0000e-06
# Epoch 121/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0020 - val_loss: 4.8801e-04 - learning_rate: 1.0000e-06
# Epoch 122/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0020 - val_loss: 4.8797e-04 - learning_rate: 1.0000e-06
# Epoch 123/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0019 - val_loss: 4.8769e-04 - learning_rate: 1.0000e-06
# Epoch 124/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0019 - val_loss: 4.8767e-04 - learning_rate: 1.0000e-06
# Epoch 125/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0018 - val_loss: 4.8779e-04 - learning_rate: 1.0000e-06
# Epoch 126/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0019 - val_loss: 4.8791e-04 - learning_rate: 1.0000e-06
# Epoch 127/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.0019 - val_loss: 4.8807e-04 - learning_rate: 1.0000e-06
# Epoch 128/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0019 - val_loss: 4.8806e-04 - learning_rate: 1.0000e-06
# Epoch 129/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0019 - val_loss: 4.8775e-04 - learning_rate: 1.0000e-06
# Epoch 130/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0018 - val_loss: 4.8763e-04 - learning_rate: 1.0000e-06
# Epoch 131/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0019 - val_loss: 4.8764e-04 - learning_rate: 1.0000e-06
# Epoch 132/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0019 - val_loss: 4.8763e-04 - learning_rate: 1.0000e-06
# Epoch 133/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0019 - val_loss: 4.8760e-04 - learning_rate: 1.0000e-06
# Epoch 134/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 0.0018 - val_loss: 4.8759e-04 - learning_rate: 1.0000e-06
# Epoch 135/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 0.0019 - val_loss: 4.8775e-04 - learning_rate: 1.0000e-06
# Epoch 136/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 0.0018 - val_loss: 4.8780e-04 - learning_rate: 1.0000e-06
# Epoch 137/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.0019 - val_loss: 4.8803e-04 - learning_rate: 1.0000e-06
# Epoch 138/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0019 - val_loss: 4.8784e-04 - learning_rate: 1.0000e-06
# Epoch 139/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.0018 - val_loss: 4.8783e-04 - learning_rate: 1.0000e-06
# Epoch 140/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.0018 - val_loss: 4.8765e-04 - learning_rate: 1.0000e-06
# Epoch 141/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 0.0019 - val_loss: 4.8763e-04 - learning_rate: 1.0000e-06
# Epoch 142/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0018 - val_loss: 4.8753e-04 - learning_rate: 1.0000e-06
# Epoch 143/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 0.0018 - val_loss: 4.8755e-04 - learning_rate: 1.0000e-06
# Epoch 144/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 0.0020 - val_loss: 4.8752e-04 - learning_rate: 1.0000e-06
# Epoch 145/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 0.0018 - val_loss: 4.8761e-04 - learning_rate: 1.0000e-06
# Epoch 146/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0018 - val_loss: 4.8751e-04 - learning_rate: 1.0000e-06
# Epoch 147/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0018 - val_loss: 4.8741e-04 - learning_rate: 1.0000e-06
# Epoch 148/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 0.0018 - val_loss: 4.8732e-04 - learning_rate: 1.0000e-06
# Epoch 149/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0017 - val_loss: 4.8761e-04 - learning_rate: 1.0000e-06
# Epoch 150/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0018 - val_loss: 4.8771e-04 - learning_rate: 1.0000e-06
# Epoch 151/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0020 - val_loss: 4.8789e-04 - learning_rate: 1.0000e-06
# Epoch 152/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0020 - val_loss: 4.8807e-04 - learning_rate: 1.0000e-06
# Epoch 153/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0019 - val_loss: 4.8809e-04 - learning_rate: 1.0000e-06
# Epoch 154/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0019 - val_loss: 4.8797e-04 - learning_rate: 1.0000e-06
# Epoch 155/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0018 - val_loss: 4.8813e-04 - learning_rate: 1.0000e-06
# Epoch 156/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0019 - val_loss: 4.8811e-04 - learning_rate: 1.0000e-06
# Epoch 157/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0016 - val_loss: 4.8809e-04 - learning_rate: 1.0000e-06
# Epoch 158/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0018 - val_loss: 4.8802e-04 - learning_rate: 1.0000e-06
# Epoch 159/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0019 - val_loss: 4.8791e-04 - learning_rate: 1.0000e-06
# Epoch 160/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0019 - val_loss: 4.8772e-04 - learning_rate: 1.0000e-06
# Epoch 161/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0017 - val_loss: 4.8753e-04 - learning_rate: 1.0000e-06
# Epoch 162/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0018 - val_loss: 4.8737e-04 - learning_rate: 1.0000e-06
# Epoch 163/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0020 - val_loss: 4.8719e-04 - learning_rate: 1.0000e-06
# Epoch 164/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0018 - val_loss: 4.8707e-04 - learning_rate: 1.0000e-06
# Epoch 165/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0019 - val_loss: 4.8710e-04 - learning_rate: 1.0000e-06
# Epoch 166/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0019 - val_loss: 4.8692e-04 - learning_rate: 1.0000e-06
# Epoch 167/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0019 - val_loss: 4.8674e-04 - learning_rate: 1.0000e-06
# Epoch 168/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0019 - val_loss: 4.8655e-04 - learning_rate: 1.0000e-06
# Epoch 169/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0019 - val_loss: 4.8646e-04 - learning_rate: 1.0000e-06
# Epoch 170/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0018 - val_loss: 4.8640e-04 - learning_rate: 1.0000e-06
# Epoch 171/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0019 - val_loss: 4.8654e-04 - learning_rate: 1.0000e-06
# Epoch 172/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0018 - val_loss: 4.8625e-04 - learning_rate: 1.0000e-06
# Epoch 173/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0018 - val_loss: 4.8607e-04 - learning_rate: 1.0000e-06
# Epoch 174/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0019 - val_loss: 4.8590e-04 - learning_rate: 1.0000e-06
# Epoch 175/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0019 - val_loss: 4.8586e-04 - learning_rate: 1.0000e-06
# Epoch 176/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0018 - val_loss: 4.8584e-04 - learning_rate: 1.0000e-06
# Epoch 177/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0020 - val_loss: 4.8592e-04 - learning_rate: 1.0000e-06
# Epoch 178/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0018 - val_loss: 4.8585e-04 - learning_rate: 1.0000e-06
# Epoch 179/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0019 - val_loss: 4.8573e-04 - learning_rate: 1.0000e-06
# Epoch 180/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0019 - val_loss: 4.8534e-04 - learning_rate: 1.0000e-06
# Epoch 181/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0017 - val_loss: 4.8533e-04 - learning_rate: 1.0000e-06
# Epoch 182/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0018 - val_loss: 4.8538e-04 - learning_rate: 1.0000e-06
# Epoch 183/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0018 - val_loss: 4.8534e-04 - learning_rate: 1.0000e-06
# Epoch 184/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0019 - val_loss: 4.8524e-04 - learning_rate: 1.0000e-06
# Epoch 185/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0019 - val_loss: 4.8524e-04 - learning_rate: 1.0000e-06
# Epoch 186/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0019 - val_loss: 4.8505e-04 - learning_rate: 1.0000e-06
# Epoch 187/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0019 - val_loss: 4.8521e-04 - learning_rate: 1.0000e-06
# Epoch 188/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0019 - val_loss: 4.8521e-04 - learning_rate: 1.0000e-06
# Epoch 189/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0019 - val_loss: 4.8509e-04 - learning_rate: 1.0000e-06
# Epoch 190/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0018 - val_loss: 4.8496e-04 - learning_rate: 1.0000e-06
# Epoch 191/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0019 - val_loss: 4.8489e-04 - learning_rate: 1.0000e-06
# Epoch 192/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0019 - val_loss: 4.8465e-04 - learning_rate: 1.0000e-06
# Epoch 193/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0018 - val_loss: 4.8474e-04 - learning_rate: 1.0000e-06
# Epoch 194/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0020 - val_loss: 4.8464e-04 - learning_rate: 1.0000e-06
# Epoch 195/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0019 - val_loss: 4.8485e-04 - learning_rate: 1.0000e-06
# Epoch 196/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0018 - val_loss: 4.8488e-04 - learning_rate: 1.0000e-06
# Epoch 197/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0018 - val_loss: 4.8483e-04 - learning_rate: 1.0000e-06
# Epoch 198/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 0.0019 - val_loss: 4.8513e-04 - learning_rate: 1.0000e-06
# Epoch 199/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 0.0018 - val_loss: 4.8494e-04 - learning_rate: 1.0000e-06
# Epoch 200/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0018 - val_loss: 4.8477e-04 - learning_rate: 1.0000e-06
# Epoch 201/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 0.0018 - val_loss: 4.8460e-04 - learning_rate: 1.0000e-06
# Epoch 202/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 0.0019 - val_loss: 4.8405e-04 - learning_rate: 1.0000e-06
# Epoch 203/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 0.0018 - val_loss: 4.8393e-04 - learning_rate: 1.0000e-06
# Epoch 204/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 0.0019 - val_loss: 4.8382e-04 - learning_rate: 1.0000e-06
# Epoch 205/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 0.0019 - val_loss: 4.8364e-04 - learning_rate: 1.0000e-06
# Epoch 206/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0019 - val_loss: 4.8355e-04 - learning_rate: 1.0000e-06
# Epoch 207/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - loss: 0.0018 - val_loss: 4.8380e-04 - learning_rate: 1.0000e-06
# Epoch 208/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - loss: 0.0018 - val_loss: 4.8358e-04 - learning_rate: 1.0000e-06
# Epoch 209/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 90ms/step - loss: 0.0018 - val_loss: 4.8337e-04 - learning_rate: 1.0000e-06
# Epoch 210/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - loss: 0.0020 - val_loss: 4.8354e-04 - learning_rate: 1.0000e-06
# Epoch 211/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 0.0018 - val_loss: 4.8357e-04 - learning_rate: 1.0000e-06
# Epoch 212/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 0.0019 - val_loss: 4.8353e-04 - learning_rate: 1.0000e-06
# Epoch 213/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 0.0019 - val_loss: 4.8356e-04 - learning_rate: 1.0000e-06
# Epoch 214/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 0.0018 - val_loss: 4.8371e-04 - learning_rate: 1.0000e-06
# Epoch 215/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0019 - val_loss: 4.8367e-04 - learning_rate: 1.0000e-06
# Epoch 216/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0018 - val_loss: 4.8367e-04 - learning_rate: 1.0000e-06
# Epoch 217/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 0.0018 - val_loss: 4.8339e-04 - learning_rate: 1.0000e-06
# Epoch 218/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - loss: 0.0019 - val_loss: 4.8334e-04 - learning_rate: 1.0000e-06
# Epoch 219/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - loss: 0.0019 - val_loss: 4.8312e-04 - learning_rate: 1.0000e-06
# Epoch 220/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 91ms/step - loss: 0.0018 - val_loss: 4.8297e-04 - learning_rate: 1.0000e-06
# Epoch 221/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 0.0018 - val_loss: 4.8288e-04 - learning_rate: 1.0000e-06
# Epoch 222/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 0.0019 - val_loss: 4.8280e-04 - learning_rate: 1.0000e-06
# Epoch 223/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - loss: 0.0019 - val_loss: 4.8297e-04 - learning_rate: 1.0000e-06
# Epoch 224/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 0.0018 - val_loss: 4.8266e-04 - learning_rate: 1.0000e-06
# Epoch 225/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: 0.0020 - val_loss: 4.8258e-04 - learning_rate: 1.0000e-06
# Epoch 226/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - loss: 0.0019 - val_loss: 4.8251e-04 - learning_rate: 1.0000e-06
# Epoch 227/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - loss: 0.0018 - val_loss: 4.8244e-04 - learning_rate: 1.0000e-06
# Epoch 228/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - loss: 0.0019 - val_loss: 4.8236e-04 - learning_rate: 1.0000e-06
# Epoch 229/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 0.0019 - val_loss: 4.8216e-04 - learning_rate: 1.0000e-06
# Epoch 230/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - loss: 0.0019 - val_loss: 4.8216e-04 - learning_rate: 1.0000e-06
# Epoch 231/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 0.0018 - val_loss: 4.8210e-04 - learning_rate: 1.0000e-06
# Epoch 232/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 0.0019 - val_loss: 4.8221e-04 - learning_rate: 1.0000e-06
# Epoch 233/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - loss: 0.0019 - val_loss: 4.8213e-04 - learning_rate: 1.0000e-06
# Epoch 234/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 0.0018 - val_loss: 4.8196e-04 - learning_rate: 1.0000e-06
# Epoch 235/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 0.0018 - val_loss: 4.8186e-04 - learning_rate: 1.0000e-06
# Epoch 236/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0018 - val_loss: 4.8187e-04 - learning_rate: 1.0000e-06
# Epoch 237/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 0.0018 - val_loss: 4.8176e-04 - learning_rate: 1.0000e-06
# Epoch 238/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0017 - val_loss: 4.8175e-04 - learning_rate: 1.0000e-06
# Epoch 239/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 0.0018 - val_loss: 4.8192e-04 - learning_rate: 1.0000e-06
# Epoch 240/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 0.0019 - val_loss: 4.8179e-04 - learning_rate: 1.0000e-06
# Epoch 241/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 0.0018 - val_loss: 4.8162e-04 - learning_rate: 1.0000e-06
# Epoch 242/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 0.0018 - val_loss: 4.8165e-04 - learning_rate: 1.0000e-06
# Epoch 243/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 0.0018 - val_loss: 4.8181e-04 - learning_rate: 1.0000e-06
# Epoch 244/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 0.0019 - val_loss: 4.8191e-04 - learning_rate: 1.0000e-06
# Epoch 245/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 0.0018 - val_loss: 4.8200e-04 - learning_rate: 1.0000e-06
# Epoch 246/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - loss: 0.0019 - val_loss: 4.8220e-04 - learning_rate: 1.0000e-06
# Epoch 247/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - loss: 0.0019 - val_loss: 4.8204e-04 - learning_rate: 1.0000e-06
# Epoch 248/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 0.0019 - val_loss: 4.8203e-04 - learning_rate: 1.0000e-06
# Epoch 249/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 0.0020 - val_loss: 4.8179e-04 - learning_rate: 1.0000e-06
# Epoch 250/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 0.0019 - val_loss: 4.8147e-04 - learning_rate: 1.0000e-06
# Epoch 251/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 0.0018 - val_loss: 4.8162e-04 - learning_rate: 1.0000e-06
# Epoch 252/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 0.0018 - val_loss: 4.8163e-04 - learning_rate: 1.0000e-06
# Epoch 253/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - loss: 0.0019 - val_loss: 4.8140e-04 - learning_rate: 1.0000e-06
# Epoch 254/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - loss: 0.0017 - val_loss: 4.8130e-04 - learning_rate: 1.0000e-06
# Epoch 255/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - loss: 0.0018 - val_loss: 4.8127e-04 - learning_rate: 1.0000e-06
# Epoch 256/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 0.0019 - val_loss: 4.8097e-04 - learning_rate: 1.0000e-06
# Epoch 257/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - loss: 0.0019 - val_loss: 4.8087e-04 - learning_rate: 1.0000e-06
# Epoch 258/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - loss: 0.0018 - val_loss: 4.8090e-04 - learning_rate: 1.0000e-06
# Epoch 259/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.0018 - val_loss: 4.8085e-04 - learning_rate: 1.0000e-06
# Epoch 260/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 0.0019 - val_loss: 4.8088e-04 - learning_rate: 1.0000e-06
# Epoch 261/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - loss: 0.0018 - val_loss: 4.8062e-04 - learning_rate: 1.0000e-06
# Epoch 262/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - loss: 0.0018 - val_loss: 4.8053e-04 - learning_rate: 1.0000e-06
# Epoch 263/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - loss: 0.0019 - val_loss: 4.8044e-04 - learning_rate: 1.0000e-06
# Epoch 264/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - loss: 0.0017 - val_loss: 4.8018e-04 - learning_rate: 1.0000e-06
# Epoch 265/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 87ms/step - loss: 0.0019 - val_loss: 4.8018e-04 - learning_rate: 1.0000e-06
# Epoch 266/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - loss: 0.0018 - val_loss: 4.8009e-04 - learning_rate: 1.0000e-06
# Epoch 267/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - loss: 0.0018 - val_loss: 4.8013e-04 - learning_rate: 1.0000e-06
# Epoch 268/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - loss: 0.0017 - val_loss: 4.8003e-04 - learning_rate: 1.0000e-06
# Epoch 269/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - loss: 0.0019 - val_loss: 4.8000e-04 - learning_rate: 1.0000e-06
# Epoch 270/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - loss: 0.0018 - val_loss: 4.7987e-04 - learning_rate: 1.0000e-06
# Epoch 271/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - loss: 0.0019 - val_loss: 4.8005e-04 - learning_rate: 1.0000e-06
# Epoch 272/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - loss: 0.0019 - val_loss: 4.7987e-04 - learning_rate: 1.0000e-06
# Epoch 273/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - loss: 0.0019 - val_loss: 4.7964e-04 - learning_rate: 1.0000e-06
# Epoch 274/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 0.0018 - val_loss: 4.7947e-04 - learning_rate: 1.0000e-06
# Epoch 275/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - loss: 0.0019 - val_loss: 4.7967e-04 - learning_rate: 1.0000e-06
# Epoch 276/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - loss: 0.0018 - val_loss: 4.7964e-04 - learning_rate: 1.0000e-06
# Epoch 277/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 93ms/step - loss: 0.0018 - val_loss: 4.7979e-04 - learning_rate: 1.0000e-06
# Epoch 278/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - loss: 0.0018 - val_loss: 4.7972e-04 - learning_rate: 1.0000e-06
# Epoch 279/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 86ms/step - loss: 0.0018 - val_loss: 4.7976e-04 - learning_rate: 1.0000e-06
# Epoch 280/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - loss: 0.0019 - val_loss: 4.7987e-04 - learning_rate: 1.0000e-06
# Epoch 281/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - loss: 0.0018 - val_loss: 4.7982e-04 - learning_rate: 1.0000e-06
# Epoch 282/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - loss: 0.0018 - val_loss: 4.7985e-04 - learning_rate: 1.0000e-06
# Epoch 283/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 0.0018 - val_loss: 4.7983e-04 - learning_rate: 1.0000e-06
# Epoch 284/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - loss: 0.0018 - val_loss: 4.7993e-04 - learning_rate: 1.0000e-06
# Epoch 285/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - loss: 0.0018 - val_loss: 4.8001e-04 - learning_rate: 1.0000e-06
# Epoch 286/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 87ms/step - loss: 0.0018 - val_loss: 4.8003e-04 - learning_rate: 1.0000e-06
# Epoch 287/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - loss: 0.0018 - val_loss: 4.8008e-04 - learning_rate: 1.0000e-06
# Epoch 288/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - loss: 0.0019 - val_loss: 4.7987e-04 - learning_rate: 1.0000e-06
# Epoch 289/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 132ms/step - loss: 0.0019 - val_loss: 4.7942e-04 - learning_rate: 1.0000e-06
# Epoch 290/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 8s 81ms/step - loss: 0.0018 - val_loss: 4.7933e-04 - learning_rate: 1.0000e-06
# Epoch 291/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 87ms/step - loss: 0.0018 - val_loss: 4.7898e-04 - learning_rate: 1.0000e-06
# Epoch 292/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - loss: 0.0019 - val_loss: 4.7873e-04 - learning_rate: 1.0000e-06
# Epoch 293/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 0.0018 - val_loss: 4.7853e-04 - learning_rate: 1.0000e-06
# Epoch 294/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - loss: 0.0019 - val_loss: 4.7854e-04 - learning_rate: 1.0000e-06
# Epoch 295/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - loss: 0.0020 - val_loss: 4.7852e-04 - learning_rate: 1.0000e-06
# Epoch 296/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - loss: 0.0018 - val_loss: 4.7872e-04 - learning_rate: 1.0000e-06
# Epoch 297/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0019 - val_loss: 4.7866e-04 - learning_rate: 1.0000e-06
# Epoch 298/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0018 - val_loss: 4.7866e-04 - learning_rate: 1.0000e-06
# Epoch 299/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0017 - val_loss: 4.7849e-04 - learning_rate: 1.0000e-06
# Epoch 300/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.0019 - val_loss: 4.7825e-04 - learning_rate: 1.0000e-06

# %% [markdown]
# # Step 11: Model Evaluation
# __Next, we evaluate our time series forecast using MAPE (Mean Absolute Percentage Error) metric:__

# %%
result = model.evaluate(X_test, y_test)
y_pred = model.predict(X_test)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.9842e-04
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step

# %%
MAPE = mean_absolute_percentage_error(y_test, y_pred)

# %%
print("Test Loss:", result)
print("Test MAPE:", MAPE)
# Out:
# Test Loss: 0.0002984219463542104
# Test MAPE: 0.05353880102747797

# %% [markdown]
# # Step 12: Visualizing Results

# %% [markdown]
# __Returning the actual and predicted Price values to their primary scale:__

# %%
y_test_true = scaler.inverse_transform(y_test)
y_test_pred = scaler.inverse_transform(y_pred)

# %% [markdown]
# __Investigating the closeness of the prices predicted by the model to the actual prices:__

# %%
plt.figure(figsize=(15, 6), dpi=150)
plt.rcParams['axes.facecolor'] = 'yellow'
plt.rc('axes',edgecolor='white')
plt.plot(df['Date'].iloc[:-test_size], scaler.inverse_transform(train_data), color='black', lw=2)
plt.plot(df['Date'].iloc[-test_size:], y_test_true, color='blue', lw=2)
plt.plot(df['Date'].iloc[-test_size:], y_test_pred, color='red', lw=2)
plt.title('Model Performance on Gold Price Prediction', fontsize=15)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.legend(['Training Data', 'Actual Test Data', 'Predicted Test Data'], loc='upper left', prop={'size': 15})
plt.grid(color='white')
plt.show()

# %%
import matplotlib.pyplot as plt

n_test_samples = len(y_test_true)
test_dates = df['Date'].iloc[-n_test_samples:]

# Create a single figure and axis
plt.figure(figsize=(12, 6), dpi=150)

# Plot both lines on the same axes
plt.plot(test_dates, y_test_true, color='blue', lw=2, label='Actual Gold Price')
plt.plot(test_dates, y_test_pred, color='red', lw=2, label=f'Predicted ({forecast_horizon}-Day Forecast)')

# Add labels and title
plt.title('Comparison: Actual vs Predicted Gold Prices', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price ($)', fontsize=12)

# Optional: Set the same Y-axis limits as before
y_min = min(y_test_true.min(), y_test_pred.min()) - 5
y_max = max(y_test_true.max(), y_test_pred.max()) + 5
plt.ylim(y_min, y_max)

# Add legend and grid
plt.legend(fontsize=12)
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Predicting Future Gold Prices
# Adjust `future_days_to_predict` to generate predictions for multiple days ahead.

# %%
future_days_to_predict = 7

last_180_days = df['Price'][-180:].values.reshape(-1, 1)

last_180_days_scaled = scaler.transform(last_180_days)
predictions = []
current_window = last_180_days_scaled.copy()

for _ in range(future_days_to_predict):
    X_input = current_window.reshape(1, 180, 1)
    next_day_scaled = model.predict(X_input, verbose=0)
    predictions.append(next_day_scaled[0, 0])
    current_window = np.append(current_window[1:], next_day_scaled, axis=0)

future_prices = scaler.inverse_transform(np.array(predictions).reshape(-1, 1))
print(f"Predicted Gold Prices for the next {future_days_to_predict} day(s):\n")
for i, price in enumerate(future_prices, start=1):
    print(f"Day {i} Forecast: {price[0]:.2f}")
# Out:
# Predicted Gold Prices for the next 7 day(s):
#
# Day 1 Forecast: 119.60
# Day 2 Forecast: 119.93
# Day 3 Forecast: 120.18
# Day 4 Forecast: 120.35
# Day 5 Forecast: 120.46
# Day 6 Forecast: 120.52
# Day 7 Forecast: 120.56
